# %% [markdown]
# <a href="https://colab.research.google.com/github/choidaesig/big_data_certificate/blob/main/%EC%9E%91%EC%97%85_1%EC%9C%A0%ED%98%95_%EB%B3%B5%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 유튜브 인기동영상 데이터/

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/youtube/youtube.csv",index_col=0)
df.head()
# Out:
#                                                title             channelTitle  \
# 0                                          [신병] 물자창고                      장삐쭈
# 1   RAIN(비) - 나로 바꾸자 Switch to me (duet with JYP) MV  RAIN's Official Channel
# 2       2020년 제야의 종 온라인 타종행사 | 보신각 현장 행사는 진행하지 않습니다.              서울시 · Seoul
# 3                                       고기남자의 칠면조 파티             고기남자 MeatMan
# 4  골목 3mc를 분노하게 만든 마음고생이 심했을 공릉 백반집 사장님의 푸념?! [예능...                    스브스밥집
#
#    categoryId  view_count  likes  dislikes  comment_count  \
# 0          23     1893473  38249       730           8595
# 1          10     2600864      0         0          20129
# 2          29      347049   3564       120            178
# 3          26      528458  15372       280           3470
# 4          24      494904   3918       111           3142
#
#                   channelId trending_date2
# 0  UChbE5OZQ6dRHECsX0tEPEZQ     2021-01-01
# 1  UCxXgIeE5hxWxHG6dz9Scg2w     2021-01-01
# ...

# %%
list(df.loc[df.channelId.isin(df.channelId.value_counts().head(10).index)].channelTitle.unique())
# Out:
# ['장삐쭈',
#  '총몇명',
#  '파뿌리',
#  '짤툰',
#  '런닝맨 - 스브스 공식 채널',
#  '엠뚜루마뚜루 : MBC 공식 종합 채널',
#  'SPOTV',
#  '채널 십오야',
#  '이과장',
#  'BANGTANTV']

# %%
list(df[df.dislikes > df.likes].channelTitle.unique())
# Out:
# ['핫도그TV',
#  'ASMR 애정TV',
#  '하얀트리HayanTree',
#  '양팡 YangPang',
#  '철구형 (CHULTUBE)',
#  '왜냐맨하우스',
#  '(MUTUBE)와꾸대장봉준',
#  '오메킴TV',
#  '육지담',
#  'MapleStory_KR',
#  'ROAD FIGHTING CHAMPIONSHIP',
#  '사나이 김기훈',
#  '나혼자산다 STUDIO',
#  'Gen.G esports']

# %%
df2=df[['channelTitle','channelId']].drop_duplicates().channelId.value_counts()

# %%
len(df2[df2>1])
# Out:
# 71

# %%
df['trending_date2']=pd.to_datetime(df['trending_date2'])

# %%
df['Day']=df['trending_date2'].dt.weekday

# %%
df[df.Day==6].categoryId.value_counts().index[0]
# Out:
# 24

# %%
gr=df.groupby([df['trending_date2'].dt.day_name(),'categoryId'],as_index=False).size()
gr.pivot(index='categoryId',columns='trending_date2')
# Out:
#                  size
# trending_date2 Friday Monday Saturday Sunday Thursday Tuesday Wednesday
# categoryId
# 1                 243    263      255    274      246     257       234
# 2                 120    105      119     99      128     119       129
# 10                833    837      776    830      890     894       917
# 15                187    215      198    217      207     208       207
# 17                633    668      592    636      682     708       706
# 19                 90     92       87     91       92      89        85
# 20                283    298      296    289      282     285       291
# 22               1288   1373     1289   1337     1341    1375      1333
# 23                568    594      570    556      560     569       566
# 24               2976   3148     3066   3096     2954    3084      3090
# 25                444    453      422    437      470     452       468
# 26                369    378      364    363      375     394       385
# ...

# %%
gr=df.groupby([df['trending_date2'].dt.day_name(),'categoryId'],as_index=False).size()

# %%
df['ratio']=df['comment_count']/df['view_count']
df
# Out:
#                                                    title  \
# 0                                              [신병] 물자창고
# 1       RAIN(비) - 나로 바꾸자 Switch to me (duet with JYP) MV
# 2           2020년 제야의 종 온라인 타종행사 | 보신각 현장 행사는 진행하지 않습니다.
# 3                                           고기남자의 칠면조 파티
# 4      골목 3mc를 분노하게 만든 마음고생이 심했을 공릉 백반집 사장님의 푸념?! [예능...
# ...                                                  ...
# 60394                       *풀코스로 먹습니다* 🍗치킨 + 🍕피자 + 🥧디저트
# 60395  [놀면 뭐하니? 예고] 우린 깐부잖아🦑 놀뭐에 등장한 월드클래스 초대손님!! MBC...
# 60396                   먹방 전쟁 : 사랑스러War (feat. 401 정육식당)
# 60397  ＂너.. 광수지?＂ 협상에 거짓말부터 던지는 광수 닮은꼴 김연경 선수 [런닝맨|21...
# 60398          ENHYPEN (엔하이픈) 'Tamed-Dashed' Official MV
#
#                   channelTitle  categoryId  view_count    likes  dislikes  \
# 0                          장삐쭈          23     1893473    38249       730
# 1      RAIN's Official Channel          10     2600864        0         0
# ...

# %%
df[df.ratio==0.161516]
# Out:
# Empty DataFrame
# Columns: [title, channelTitle, categoryId, view_count, likes, dislikes, comment_count, channelId, trending_date2, ratio]
# Index: []

# %%
df.sort_values(by='ratio',ascending=False).head(10)
t=df.loc[df.view_count!=0]
t
# Out:
#                                                    title  \
# 0                                              [신병] 물자창고
# 1       RAIN(비) - 나로 바꾸자 Switch to me (duet with JYP) MV
# 2           2020년 제야의 종 온라인 타종행사 | 보신각 현장 행사는 진행하지 않습니다.
# 3                                           고기남자의 칠면조 파티
# 4      골목 3mc를 분노하게 만든 마음고생이 심했을 공릉 백반집 사장님의 푸념?! [예능...
# ...                                                  ...
# 60394                       *풀코스로 먹습니다* 🍗치킨 + 🍕피자 + 🥧디저트
# 60395  [놀면 뭐하니? 예고] 우린 깐부잖아🦑 놀뭐에 등장한 월드클래스 초대손님!! MBC...
# 60396                   먹방 전쟁 : 사랑스러War (feat. 401 정육식당)
# 60397  ＂너.. 광수지?＂ 협상에 거짓말부터 던지는 광수 닮은꼴 김연경 선수 [런닝맨|21...
# 60398          ENHYPEN (엔하이픈) 'Tamed-Dashed' Official MV
#
#                   channelTitle  categoryId  view_count    likes  dislikes  \
# 0                          장삐쭈          23     1893473    38249       730
# 1      RAIN's Official Channel          10     2600864        0         0
# ...

# %%
t['rr']=t['comment_count']/t['view_count'].dropna()
# Out:
# <ipython-input-38-d207c097d290>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t['rr']=t['comment_count']/t['view_count'].dropna()

# %%
t.sort_values(by='rr',ascending=False).title.head(1).iloc[0]
# Out:
# '60분 동안 댓글이 달리지 않으면, 영상이 삭제됩니다. (챌린지)'

# %%
df2=df[df.view_count!=0]

# %%
df2['low']=df.comment_count/df.view_count
df2=df2[df2.low>0]
df2.sort_values(by='low').title.iloc[0]
# Out:
# 'Join the BTS #PermissiontoDance Challenge only on YouTube #Shorts'

# %%
df3=df[(df.likes!=0)&(df.dislikes!=0)]

# %%
df3['diss']=df.dislikes/df.likes
df3.sort_values(by='diss').title.iloc[0]
# Out:
# <ipython-input-24-101e07565150>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['diss']=df.dislikes/df.likes
# '[줌터뷰] *최초공개* 사부작즈🐰🐶의 비공식 이름은 아이라인즈? 꿀조합 티키타카 가득한 NCT 127 도영&정우의 줌터뷰'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60399 entries, 0 to 60398
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           60399 non-null  object
#  1   channelTitle    60399 non-null  object
#  2   categoryId      60399 non-null  int64
#  3   view_count      60399 non-null  int64
#  4   likes           60399 non-null  int64
#  5   dislikes        60399 non-null  int64
#  6   comment_count   60399 non-null  int64
#  7   channelId       60399 non-null  object
#  8   trending_date2  60399 non-null  datetime64[ns]
#  9   Day             60399 non-null  int32
# dtypes: datetime64[ns](1), int32(1), int64(5), object(3)
# memory usage: 6.9+ MB

# %%
df[df.channelId==df.channelId.value_counts().index[0]].channelTitle.iloc[0]
# Out:
# '짤툰'

# %%
ans=df.channelId.value_counts()>=20
ans2=df[['title','channelId']].value_counts()>=20
# Out:
# 775

# %% [markdown]
# # 유튜브 공범컨텐츠 동영상 데이터

# %%
import pandas as pd
import pandas as pd


channel =pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/youtube/channelInfo.csv')
video =pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/youtube/videoInfo.csv')
display(channel.head())
display(video.head())
# Out:
#                   channelid   subcnt    viewcnt  videocnt  \
# 0  UCkQCwnkQfgSuPTTnw_Y7v7w  1310000  410238653       736
# 1  UCkQCwnkQfgSuPTTnw_Y7v7w  1310000  412531322       736
# 2  UCkQCwnkQfgSuPTTnw_Y7v7w  1310000  412531322       735
# 3  UCkQCwnkQfgSuPTTnw_Y7v7w  1310000  412531322       737
# 4  UCkQCwnkQfgSuPTTnw_Y7v7w  1320000  412531322       737
#
#                     ct channelname
# 0  2021-09-30 03:01:03         꽈뚜룹
# 1  2021-09-30 09:01:03         꽈뚜룹
# 2  2021-09-30 15:01:03         꽈뚜룹
# 3  2021-09-30 21:01:03         꽈뚜룹
# 4  2021-10-01 03:01:04         꽈뚜룹
#        videopk  viewcnt  likecnt  dislikecnt  favoritecnt  cmcnt  \
# 0  c5JQp6xafqc  1667010    30474         706            0   6587
# 1  c5JQp6xafqc  1669089    30495         707            0   6589
# 2  c5JQp6xafqc  1674759    30522         711            0   6596
# 3  c5JQp6xafqc  1677026    30555         712            0   6604
# 4  c5JQp6xafqc  1681824    30585         713            0   6600
#
# ...

# %%
channel.info()
video.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1395 entries, 0 to 1394
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   channelid    1395 non-null   object
#  1   subcnt       1395 non-null   int64
#  2   viewcnt      1395 non-null   int64
#  3   videocnt     1395 non-null   int64
#  4   ct           1395 non-null   object
#  5   channelname  1395 non-null   object
# dtypes: int64(3), object(3)
# memory usage: 65.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15201 entries, 0 to 15200
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   videopk      15201 non-null  object
#  1   viewcnt      15201 non-null  int64
#  2   likecnt      15201 non-null  int64
#  3   dislikecnt   15201 non-null  int64
#  4   favoritecnt  15201 non-null  int64
#  5   cmcnt        15201 non-null  int64
#  6   ct           15201 non-null  object
# ...

# %%
#각 데이터의 ‘ct’컬럼을 시간으로 인식할수 있게 datatype을 변경하고 video 데이터의 videoname의 각 value 마다 몇개의 데이터씩 가지고 있는지 확인하라


pd.to_datetime(channel.ct)
pd.to_datetime(video.ct)
# Out:
# 0       2021-10-10 15:20:03
# 1       2021-10-10 15:30:03
# 2       2021-10-10 15:40:02
# 3       2021-10-10 15:50:03
# 4       2021-10-10 16:00:03
#                 ...
# 15196   2021-11-01 14:50:06
# 15197   2021-11-01 15:00:05
# 15198   2021-11-01 15:10:05
# 15199   2021-11-01 15:20:04
# 15200   2021-11-01 15:30:05
# Name: ct, Length: 15201, dtype: datetime64[ns]

# %%
video.groupby('videoname').size()
# Out:
# videoname
#  공범 EP1    3492
#  공범 EP2    3204
#  공범 EP3    2568
#  공범 EP4    2280
#  공범 EP5    1562
#  공범 EP6    1274
#  공범 EP7     555
#  공범 EP8     266
# dtype: int64

# %%
#수집된 각 video의 가장 최신화 된 날짜의 viewcount값을 출력하라

video.sort_values(['ct','videoname']).drop_duplicates('videoname',keep='last')[['viewcnt','videoname','ct']].reset_index(drop=True)
# Out:
#    viewcnt videoname                   ct
# 0  3180532    공범 EP1  2021-11-01 15:30:03
# 1  2199328    공범 EP2  2021-11-01 15:30:03
# 2  1671294    공범 EP3  2021-11-01 15:30:03
# 3  1818493    공범 EP4  2021-11-01 15:30:03
# 4  1503435    공범 EP5  2021-11-01 15:30:04
# 5  1750222    공범 EP6  2021-11-01 15:30:04
# 6  1630200    공범 EP7  2021-11-01 15:30:05
# 7  1289088    공범 EP8  2021-11-01 15:30:05

# %%
#Channel 데이터중 2021-10-03일 이후 각 채널의 처음 기록 됐던 구독자 수(subcnt)를 출력하라

channel[channel.ct >= '2021-10-03'].drop_duplicates('channelname',keep='first')[['channelname','subcnt']].reset_index(drop=True).sort_values('channelname')
# Out:
#         channelname   subcnt
# 10    Balming Tiger    54300
# 9     곽토리 kwak tori   471000
# 7        김농밀의 농밀한 삶     7520
# 0               꽈뚜룹  1330000
# 3            논리왕 전기   922000
# 8       릴펄 Lilpearl    10100
# 1             야전삽짱재   257000
# 4   와글와글 WagleWagle    55000
# 5               조나단   215000
# 2        츄정ChuJeong   322000
# 6           형사!탐정되다    14900

# %%
#각채널의 2021-10-03 03:00:00 ~ 2021-11-01 15:00:00 까지 구독자수 (subcnt) 의 증가량을 구하여라ch
channel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1395 entries, 0 to 1394
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   channelid    1395 non-null   object
#  1   subcnt       1395 non-null   int64
#  2   viewcnt      1395 non-null   int64
#  3   videocnt     1395 non-null   int64
#  4   ct           1395 non-null   object
#  5   channelname  1395 non-null   object
# dtypes: int64(3), object(3)
# memory usage: 65.5+ KB

# %%
first=channel[channel.ct >= '2021-10-03 03:00:00'].drop_duplicates('channelname',keep='first').reset_index(drop=True)
last=channel[channel.ct <= '2021-11-01 15:00:00'].drop_duplicates('channelname',keep='last').reset_index(drop=True)

# %%
c=first.copy()
first.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   channelid    11 non-null     object
#  1   subcnt       11 non-null     int64
#  2   viewcnt      11 non-null     int64
#  3   videocnt     11 non-null     int64
#  4   ct           11 non-null     object
#  5   channelname  11 non-null     object
# dtypes: int64(3), object(3)
# memory usage: 656.0+ bytes

# %%
c['last']=last['subcnt']
c['first']=first['subcnt']

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   channelid    11 non-null     object
#  1   subcnt       11 non-null     int64
#  2   viewcnt      11 non-null     int64
#  3   videocnt     11 non-null     int64
#  4   ct           11 non-null     object
#  5   channelname  11 non-null     object
#  6   last         11 non-null     int64
#  7   first        11 non-null     int64
# dtypes: int64(5), object(3)
# memory usage: 832.0+ bytes

# %%
c['del']=c['last']-c['first']
c[['channelname','del']]
# Out:
#         channelname    del
# 0               꽈뚜룹  70000
# 1             야전삽짱재  11000
# 2        츄정ChuJeong   1000
# 3            논리왕 전기 -11000
# 4   와글와글 WagleWagle      0
# 5               조나단  12000
# 6           형사!탐정되다  10300
# 7        김농밀의 농밀한 삶   1540
# 8       릴펄 Lilpearl  11000
# 9     곽토리 kwak tori  -2000
# 10    Balming Tiger   2500

# %%
#각 비디오는 10분 간격으로 구독자수, 좋아요, 싫어요수, 댓글수가 수집된것으로 알려졌다. 공범 EP1의 비디오정보 데이터중 수집간격이 5분 이하, 20분이상인 데이터 구간( 해당 시점 전,후) 의 시각을 모두 출력하라
import datetime

ep_one=video[video.videoname.str.contains('1')].reset_index(drop=True)

# %%
ep_one[
    (ep_one.ct.diff(1) >= datetime.timedelta(minutes=20)) | (ep_one.ct.diff(1) <= datetime.timedelta(minutes=5))
]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-135-a00f940f92f6> in <cell line: 1>()
#       1 ep_one[
# ----> 2     (ep_one.ct.diff(1) >= datetime.timedelta(minutes=20)) | (ep_one.ct.diff(1) <= datetime.timedelta(minutes=5))
#       3 ]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in diff(self, periods)
#    2868         {examples}
#    2869         """
# -> 2870         result = algorithms.diff(self._values, periods)
#    2871         return self._constructor(result, index=self.index, copy=False).__finalize__(
#    2872             self, method="diff"
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/algorithms.py in diff(arr, n, axis)
#    1452         lag_indexer = tuple(_lag_indexer)
#    1453
# -> 1454         out_arr[res_indexer] = op(arr[res_indexer], arr[lag_indexer])
#    1455
#    1456     if is_timedelta:
#
# ...

# %%
#각 에피소드의 시작날짜(년-월-일)를 에피소드 이름과 묶어 데이터 프레임으로 만들고 출력하라\
video['date']=video.drop_duplicates('videoname',keep='first').ct.dt.date

# %%
video['ct']=pd.to_datetime(video['ct'])

# %%
video[['date','videoname']].drop_duplicates('videoname',keep='first')
# Out:
#              date videoname
# 0      2021-10-10    공범 EP1
# 3492   2021-10-10    공범 EP2
# 6696   2021-10-14    공범 EP3
# 9264   2021-10-16    공범 EP4
# 11544  2021-10-21    공범 EP5
# 13106  2021-10-28    공범 EP7
# 13661  2021-10-23    공범 EP6
# 14935  2021-10-30    공범 EP8

# %%
#“공범” 컨텐츠의 경우 19:00시에 공개 되는것으로 알려져있다. 공개된 날의 21시의 viewcnt, ct, videoname 으로 구성된 데이터 프레임을 viewcnt를 내림차순으로 정렬하여 출력하라
import datetime

video['time']=video.ct.dt.hour

# %%
video[video.time==21].drop_duplicates('videoname',keep='first')[['videoname','viewcnt','ct']].reset_index(drop=True)
# Out:
#   videoname  viewcnt                  ct
# 0    공범 EP1   117340 2021-10-07 21:00:03
# 1    공범 EP2   148144 2021-10-09 21:00:03
# 2    공범 EP3   147183 2021-10-14 21:00:04
# 3    공범 EP4   217674 2021-10-16 21:00:04
# 4    공범 EP5   201179 2021-10-21 21:00:04
# 5    공범 EP7   252032 2021-10-28 21:00:04
# 6    공범 EP6   213899 2021-10-23 21:00:06
# 7    공범 EP8   264029 2021-10-30 21:00:08

# %%
#video 정보의 가장 최근 데이터들에서 각 에피소드의 싫어요/좋아요 비율을 ratio 컬럼으로 만들고 videoname, ratio로 구성된 데이터 프레임을 ratio를 오름차순으로 정렬하라
recent=video.drop_duplicates('videoname',keep='last')
recent['ratio']=recent.dislikecnt/recent.likecnt
recent[['videoname','ratio']].sort_values('ratio').reset_index(drop=True)
# Out:
# <ipython-input-178-c10bab420245>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recent['ratio']=recent.dislikecnt/recent.likecnt
#   videoname     ratio
# 0    공범 EP7  0.013636
# 1    공범 EP6  0.015881
# 2    공범 EP4  0.017971
# 3    공범 EP5  0.021128
# 4    공범 EP3  0.022360
# 5    공범 EP1  0.027118
# 6    공범 EP2  0.029844
# 7    공범 EP8  0.141357

# %%
#video 데이터 중에서 중복되는 데이터가 존재한다. 중복되는 각 데이터의 시간대와 videoname 을 구하여라
ans=video[video.index.isin(set(video.index) - set(video.drop_duplicates().index))]
ans
# Out:
#           videopk  viewcnt  likecnt  dislikecnt  favoritecnt  cmcnt  \
# 722   c5JQp6xafqc  2228250    34559         849            0   7191
# 3927  23QQ1ru9YQg  1408005    20484         554            0   8567
#
#                       ct videoname date  time     ratio
# 722  2021-10-13 09:41:37    공범 EP1  NaN     9  0.024567
# 3927 2021-10-13 09:41:37    공범 EP2  NaN     9  0.027045

# %% [markdown]
# # 월드컵 출전선수 골기록 데이터

# %%
import pandas as pd

df= pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/worldcup/worldcupgoals.csv')
df.head()
# Out:
#            Player  Goals                Years  Country
# 0  Miroslav Klose     16  2002-2006-2010-2014  Germany
# 1         Ronaldo     15       1998-2002-2006   Brazil
# 2     Gerd Muller     14            1970-1974  Germany
# 3   Just Fontaine     13                 1958   France
# 4            Pele     12  1958-1962-1966-1970   Brazil

# %%
#주어진 전체 기간의 각 나라별 골득점수 상위 5개 국가와 그 득점수를 데이터프레임형태로 출력하라
ans=df.groupby('Country')['Goals'].sum().sort_values(ascending=False)
ans.head()
# Out:
# Country
# Brazil       228
# Germany      226
# Argentina    135
# Italy        123
# France       115
# Name: Goals, dtype: int64

# %%
# 주어진 전체기간동안 골득점을 한 선수가 가장 많은 나라 상위 5개 국가와 그 선수 숫자를 데이터 프레임 형식으로 출력하라
ans=df.groupby('Country').size().sort_values(ascending=False)

# %%
#Years 컬럼은 년도 -년도 형식으로 구성되어있고, 각 년도는 4자리 숫자이다. 년도 표기가 4자리 숫자로 안된 케이스가 존재한다. 해당 건은 몇건인지 출력하라
df['yearLst']=df.Years.str.split('-')

def check(x):
  for i in x:
    if len(str(i)) != 4:
      return False

  return True

df['check']=df.yearLst.apply(check)

len(df[df.check==False])
# Out:
# 45

# %%
#**Q3에서 발생한 예외 케이스를 제외한 데이터프레임을 df2라고 정의하고 데이터의 행의 숫자를 출력하라 (아래 문제부터는 df2로 풀이하겠습니다) **
df2=df[df.check==True]
len(df2)
# Out:
# 1250

# %%
# 월드컵 출전횟수를 나타내는 ‘LenCup’ 컬럼을 추가하고 4회 출전한 선수의 숫자를 구하여라

def cnt(x):
  t=0
  for i in x:
    t+=1
  return t

df['cnt']=df.yearLst.apply(cnt)
len(df[df.cnt==4])
# Out:
# 16

# %%
df2['Lencup']=df2.yearLst.str.len()
df2.Lencup.value_counts()[4]
# Out:
# <ipython-input-240-0d35c47ea750>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Lencup']=df2.yearLst.str.len()
# 16

# %%
#Yugoslavia 국가의 월드컵 출전횟수가 2회인 선수들의 숫자를 구하여라
len(df[(df.Country=='Yugoslavia')&(df.cnt==2)])
# Out:
# 7

# %%
#2002년도에 출전한 전체 선수는 몇명인가?
len(df[df.Years.str.contains('2002')])
# Out:
# 156

# %%
# 이름에 ‘carlos’ 단어가 들어가는 선수의 숫자는 몇 명인가? (대, 소문자 구분 x)

df.Player=df.Player.str.lower()
len(df[df.Player.str.contains('carlos')])
# Out:
# 13

# %%
#월드컵 출전 횟수가 1회뿐인 선수들 중에서 가장 많은 득점을 올렸던 선수는 누구인가?
df[df.cnt==1].iloc[0].Player
# Out:
# 'just fontaine'

# %%
df[df.cnt==1].groupby('Country').size().sort_values(ascending=False).index[0]
# Out:
# 'Brazil'

# %% [markdown]
# # 서울시 따릉이 이용정보 데이터

# %%
import pandas as pd
df =pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/bicycle/seoul_bi.csv')
df.head()
# Out:
#          대여일자  대여시간  대여소번호 대여구분코드 성별 연령대코드  이용건수    운동량   탄소량     이동거리  사용시간
# 0  2021-06-01     0   3541    정기권  F  ~10대     1   0.00  0.00     0.00     8
# 1  2021-06-01     0    765    정기권  F  ~10대     1  27.21  0.35  1526.81    19
# 2  2021-06-01     0   2637    정기권  F  ~10대     1  41.40  0.37  1608.56    18
# 3  2021-06-01     0   2919    정기권  F  ~10대     1   0.00  0.00     0.00    75
# 4  2021-06-01     0    549    정기권  F  ~10대     1  13.04  0.17   731.55     6

# %%
#대여일자별 데이터의 수를 데이터프레임으로 출력하고, 가장 많은 데이터가 있는 날짜를 출력하라
df.groupby('대여일자').size().to_frame()
# Out:
#                 0
# 대여일자
# 2021-06-01  48081
# 2021-06-02  56100
# 2021-06-03  18985
# 2021-06-04  56788
# 2021-06-05  52730
# 2021-06-06  47787
# 2021-06-07  52623
# 2021-06-08  55623
# 2021-06-09  54507
# 2021-06-10  36992
# 2021-06-11  52089
# 2021-06-12  48569
# 2021-06-13  43131
# 2021-06-14  54945

# %%
df.groupby('대여일자').size().sort_values(ascending=False).index[0]
# Out:
# '2021-06-04'

# %%
#각 일자의 요일을 표기하고 (‘Monday’ ~’Sunday’) ‘day_name’컬럼을 추가하고 이를 이용하여 각 요일별 이용 횟수의 총합을 데이터 프레임으로 출력하라
df.대여일자=pd.to_datetime(df.대여일자)
df['day_name']=df.대여일자.dt.day_name()
df.groupby('day_name').size().sort_values()
# Out:
# day_name
# Thursday      55977
# Sunday        90918
# Saturday     101299
# Tuesday      103704
# Monday       107568
# Friday       108877
# Wednesday    110607
# dtype: int64

# %%
#각 요일별 가장 많이 이용한 대여소의 이용횟수와 대여소 번호를 데이터 프레임으로 출력하라

ans=df.groupby(['day_name','대여소번호']).size().to_frame('size').reset_index().sort_values('size')
ans.drop_duplicates('day_name',keep='last')
# Out:
#         day_name  대여소번호  size
# 11482   Thursday   2715   137
# 2769      Monday    502   242
# 12421    Tuesday    502   267
# 348       Friday    502   277
# 14820  Wednesday    502   282
# 7611      Sunday    502   372
# 5191    Saturday    502   378

# %%
#연령대별 평균 이동거리를 구하여라
df.groupby('연령대코드')['이동거리'].mean()
# Out:
# 연령대코드
# 20대     3211.890552
# 30대     3341.443859
# 40대     3514.857416
# 50대     3593.668100
# 60대     3538.145737
# 70대~    3085.039641
# ~10대    2634.426279
# Name: 이동거리, dtype: float64

# %%
#연령대 코드가 20대인 데이터를 추출하고,이동거리값이 추출한 데이터의 이동거리값의 평균 이상인 데이터를 추출한다.최종 추출된 데이터를 대여일자, 대여소 번호 순서로 내림차순 정렬 후 1행부터 200행까지의 탄소량의 평균을 소숫점 3째 자리까지 구하여라

df.head()
# Out:
#         대여일자  대여시간  대여소번호 대여구분코드 성별 연령대코드  이용건수    운동량   탄소량     이동거리  사용시간  \
# 0 2021-06-01     0   3541    정기권  F  ~10대     1   0.00  0.00     0.00     8
# 1 2021-06-01     0    765    정기권  F  ~10대     1  27.21  0.35  1526.81    19
# 2 2021-06-01     0   2637    정기권  F  ~10대     1  41.40  0.37  1608.56    18
# 3 2021-06-01     0   2919    정기권  F  ~10대     1   0.00  0.00     0.00    75
# 4 2021-06-01     0    549    정기권  F  ~10대     1  13.04  0.17   731.55     6
#
#   day_name
# 0  Tuesday
# 1  Tuesday
# 2  Tuesday
# 3  Tuesday
# 4  Tuesday

# %%
#이동거리의 평균 이상의 이동거리 값을 가지는 데이터를 추출하여 추출데이터의 이동거리의 표본표준편차 값을 구하여라
df[df.이동거리 >= df.이동거리.mean()].이동거리.std()
# Out:
# 5092.139707505356

# %%
#남성(‘M’ or ‘m’)과 여성(‘F’ or ‘f’)의 이동거리값의 평균값을 구하여라

df['sex']=df['성별'].map(lambda x: '남' if x in ['m','M'] else '여')
df.groupby('sex').이동거리.mean()
# Out:
# sex
# 남    3209.110871
# 여    3468.575025
# Name: 이동거리, dtype: float64

# %%
# 6월 7일 ~10대의 “이용건수”의 중앙값은?

df[(df.대여일자 == '2021-06-07') & (df.연령대코드=='~10대')].이용건수.median()
# Out:
# 1.0

# %% [markdown]
# # 전세계 행복도 지표 데이터

# %%
import pandas as pd
df =pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/happy2/happiness.csv',encoding='utf-8')
df.head()
# Out:
#    행복랭킹          나라명     점수  상대GDP  사회적지원  행복기대치  선택의 자유도    관대함  부패에 대한인식  \
# 0     1      Finland  7.769  1.340  1.587  0.986    0.596  0.153     0.393
# 1     2      Denmark  7.600  1.383  1.573  0.996    0.592  0.252     0.410
# 2     3       Norway  7.554  1.488  1.582  1.028    0.603  0.271     0.341
# 3     4      Iceland  7.494  1.380  1.624  1.026    0.591  0.354     0.118
# 4     5  Netherlands  7.488  1.396  1.522  0.999    0.557  0.322     0.298
#
#      년도
# 0  2019
# 1  2019
# 2  2019
# 3  2019
# 4  2019

# %%
# 데이터는 2018년도와 2019년도의 전세계 행복 지수를 표현한다. 각년도의 행복랭킹 10위를 차지한 나라의 행복점수의 평균을 구하ㅇ
df1=df[(df.년도 == 2018)&(df.행복랭킹==10)].reset_index()
df2=df[(df.년도 == 2019)&(df.행복랭킹==10)].reset_index()
(df1.점수+df2.점수)/2
# Out:
# 0    7.259
# Name: 점수, dtype: float64

# %%
df[df.행복랭킹 == 10].점수.mean()
# Out:
# 7.259

# %%
#데이터는 2018년도와 2019년도의 전세계 행복 지수를 표현한다. 각년도의 행복랭킹 50위이내의 나라들의 각각의 행복점수 평균을 데이터프레임으로 표시하라
df[df.행복랭킹<=50].groupby('년도').점수.mean()
# Out:
# 년도
# 2018    6.64678
# 2019    6.67002
# Name: 점수, dtype: float64

# %%
# 2018년도 데이터들만 추출하여 행복점수와 부패에 대한 인식에 대한 상관계수를 구하여라
df[df.년도==2018][['점수','부패에 대한인식']].corr().iloc[0,1]
# Out:
# 0.40529152271510027

# %%
# 2018년도와 2019년도의 행복랭킹이 변화하지 않은 나라명의 수를 구하여라
len(df[['행복랭킹','나라명']])-len(df[['행복랭킹','나라명']].drop_duplicates())
# Out:
# 15

# %%
# 각 년도별 하위 행복점수의 하위 5개 국가의 평균 행복점수를 구하여라

df.groupby('년도').tail(5).groupby('년도')[['점수']].mean()
# Out:
#           점수
# 년도
# 2018  3.1800
# 2019  3.1408

# %%
# 2019년 데이터를 추출하고 해당데이터의 상대 GDP 평균 이상의 나라들과 평균 이하의 나라들의 행복점수 평균을 각각 구하고 그 차이값을 출력하라
over=df[(df.년도 == 2019)&(df.상대GDP>= df.상대GDP.mean())].점수.mean()
down=df[(df.년도 == 2019)&(df.상대GDP<=df.상대GDP.mean())].점수.mean()
over-down
# Out:
# 1.390483957219251

# %%
# 각년도의 부패에 대한인식을 내림차순 정렬했을때 상위 20개 국가의 부패에 대한인식의 평균을 구하여라
df.sort_values(['년도','부패에 대한인식'],ascending=False).groupby('년도').head(20).groupby('년도')['부패에 대한인식'].mean()
# Out:
# 년도
# 2018    0.3267
# 2019    0.3201
# Name: 부패에 대한인식, dtype: float64

# %%
#2018년도 행복랭킹 50위 이내에 포함됐다가 2019년 50위 밖으로 밀려난 국가의 숫자를 구하여라
set(df[(df.년도 == 2018) & (df.행복랭킹 <= 50)].나라명)-set(df[(df.년도 == 2019) & (df.행복랭킹 <= 50)].나라명)
# Out:
# {'Belize', 'Kuwait', 'Malaysia', 'Thailand'}

# %%
# 2018년,2019년 모두 기록이 있는 나라들 중 년도별 행복점수가 가장 증가한 나라와 그 증가 수치는?
count=df.나라명.value_counts()
target=count[count>=2].index

df2=df.copy()
mul=df[df2.나라명.isin(target)].reset_index(drop=True)
mul.loc[mul['년도']==2018,'점수'] = mul[mul.년도 ==2018]['점수'] * (-1)

mul.groupby('나라명').sum().점수.sort_values()
# Out:
# 나라명
# Malaysia       -0.983
# Afghanistan    -0.429
# South Sudan    -0.401
# Turkmenistan   -0.389
# Somalia        -0.314
#                 ...
# Niger           0.462
# Liberia         0.480
# Guinea          0.570
# Benin           0.742
# Burundi         0.870
# Name: 점수, Length: 152, dtype: float64

# %% [markdown]
# # 지역구 에너지 소비량 데이터

# %%
import pandas as pd
df= pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/consum/Tetuan%20City%20power%20consumption.csv')
df.head()
# Out:
#         DateTime  Temperature  Humidity  Wind Speed  general diffuse flows  \
# 0  1/1/2017 0:00        6.559      73.8       0.083                  0.051
# 1  1/1/2017 0:10        6.414      74.5       0.083                  0.070
# 2  1/1/2017 0:20        6.313      74.5       0.080                  0.062
# 3  1/1/2017 0:30        6.121      75.0       0.083                  0.091
# 4  1/1/2017 0:40        5.921      75.7       0.081                  0.048
#
#    diffuse flows  Zone 1 Power Consumption  Zone 2  Power Consumption  \
# 0          0.119               34055.69620                16128.87538
# 1          0.085               29814.68354                19375.07599
# 2          0.100               29128.10127                19006.68693
# 3          0.096               28228.86076                18361.09422
# 4          0.085               27335.69620                17872.34043
#
#    Zone 3  Power Consumption
# 0                20240.96386
# 1                20131.08434
# ...

# %%
# DateTime컬럼을 통해 각 월별로 몇개의 데이터가 있는지 데이터 프레임으로 구하여라
df.DateTime=pd.to_datetime(df['DateTime'])
df['DateTime'].dt.month.value_counts().sort_index()
# Out:
# DateTime
# 1     4464
# 2     4032
# 3     4464
# 4     4320
# 5     4464
# 6     4320
# 7     4464
# 8     4464
# 9     4320
# 10    4464
# 11    4320
# 12    4320
# Name: count, dtype: int64

# %%
# 3월달의 각 시간대별 온도의 평균들 중 가장 낮은 시간대의 온도를 출력하라

target = df[df.DateTime.dt.month ==3]
result = target.groupby(target.DateTime.dt.hour)['Temperature'].mean().sort_values().values[0]
print(result)
# Out:
# 11.506612903225806

# %%
# 3월달의 각 시간대별 온도의 평균들 중 가장 높은 시간대의 온도를 출력하라

target=df[df.DateTime.dt.month == 3]

target.groupby(target['DateTime'].dt.hour).Temperature.mean().sort_values().tail(1).iloc[0]
# Out:
# 18.393602150537635

# %%
#Zone 1 Power Consumption 컬럼의 value값의 크기가 Zone 2 Power Consumption 컬럼의 value값의 크기보다 큰 데이터들의 Humidity의 평균을 구하여라
df[df['Zone 1 Power Consumption']>=df['Zone 2  Power Consumption']].Humidity.mean()
# Out:
# 68.23624448055052

# %%
df.iloc[:,-3:].corr()
# Out:
#                            Zone 1 Power Consumption  \
# Zone 1 Power Consumption                   1.000000
# Zone 2  Power Consumption                  0.834519
# Zone 3  Power Consumption                  0.750733
#
#                            Zone 2  Power Consumption  \
# Zone 1 Power Consumption                    0.834519
# Zone 2  Power Consumption                   1.000000
# Zone 3  Power Consumption                   0.570932
#
#                            Zone 3  Power Consumption
# Zone 1 Power Consumption                    0.750733
# Zone 2  Power Consumption                   0.570932
# Zone 3  Power Consumption                   1.000000

# %%
def grade(x):
  if x <10:
    return 'A'
  elif x< 20:
    return 'B'
  elif x< 30:
    return 'C'
  else:
    return 'D'

df['grade']=df.Temperature.apply(grade)
df.groupby('grade').size()
# Out:
# grade
# A     2874
# B    26993
# C    21105
# D     1444
# dtype: int64

# %%
df[(df.DateTime.dt.hour==12) & (df.DateTime.dt.month==6)].Temperature.std()
# Out:
# 2.0499417827951025

# %%
df[(df.DateTime.dt.hour==12) & (df.DateTime.dt.month==6)].Temperature.var()
# Out:
# 4.202261312849163

# %%
df[df.Temperature >= df.Temperature.mean()].sort_values(by='Temperature').Humidity.iloc[3]
# Out:
# 87.9

# %%
df[df.Temperature >= df.Temperature.median()].sort_values(by='Temperature').Humidity.iloc[3]
# Out:
# 80.3

# %% [markdown]
# # 포켓몬 정보 데이터

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/pok/Pokemon.csv')
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
#Legendary 컬럼은 전설포켓몬 유무를 나타낸다.전설포켓몬과 그렇지 않은 포켓몬들의 HP평균의 차이를 구하여라

df[df.Legendary==True].HP.mean() - df[df.Legendary==False].HP.mean()
# Out:
# 25.55614861329147

# %%
#Type 1은 주속성 Type 2 는 부속성을 나타낸다. 가장 많은 부속성 종류는 무엇인가?
df.groupby('Type 2').size().sort_values().tail(1).index[0]
# Out:
# 'Flying'

# %%
df['Type 2'].value_counts().index[0]
# Out:
# 'Flying'

# %%
#가장 많은 Type 1 의 종의 평균 Attack 을 평균 Defense로 나눈값은?

max=df['Type 1'].value_counts().index[0]
df[df['Type 1']==max].Attack.mean() / df[df['Type 1']==max].Defense.mean()
# Out:
# 1.0165238678090576

# %%
# 포켓몬 세대(Generation) 중 가장많은 Legendary를 보유한 세대는 몇세대인가?
df[df.Legendary==True].Generation.value_counts().index[0]
# Out:
# 3

# %%
# 각 Generation의 Attack으로 오름차순 정렬시 상위 3개 데이터들(18개)의 Attack의 전체 평균을 구하여라
df.sort_values(['Generation','Attack']).groupby('Generation').head(3).Attack.mean()
# Out:
# 19.5

# %%
df.sort_values(['Generation','Attack'],ascending=False).groupby('Generation').head(5).Attack.mean()
# Out:
# 157.23333333333332

# %%
df[['Type 1','Type 2']].value_counts().head(1)
# Out:
# Type 1  Type 2
# Normal  Flying    24
# Name: count, dtype: int64

# %%
target = df[['Type 1','Type 2']].value_counts()
result = len(target[target==1])
print(result)
# Out:
# 39

# %%
target = df[['Type 1','Type 2']].value_counts()
target2 =target[target==1]

lst = []
for value in target2.reset_index().values:
    t1 = value[0]
    t2 = value[1]

    sp = df[(df['Type 1']==t1) & (df['Type 2']==t2)]
    lst.append(sp)

result = pd.concat(lst).reset_index(drop=True).Generation.value_counts().sort_index()
print(result)
# Out:
# Generation
# 1     1
# 2     4
# 3     5
# 4    13
# 5     7
# 6     9
# Name: count, dtype: int64

# %% [markdown]
# # 대한민국 체력장 데이터

# %%
import pandas as pd
df =pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/body/body.csv')
df.head()
# Out:
#    측정나이 측정회원성별  신장 : cm  체중 : kg  체지방율 : %  이완기혈압(최저) : mmHg  \
# 0  59.0      M    175.0     70.6      19.2              91.0
# 1  40.0      F    161.4     45.8      21.7              62.0
# 2  27.0      M    176.6     84.8      19.2              87.0
# 3  38.0      M    167.6     76.7      24.7              63.0
# 4  21.0      M    165.2     66.2      21.5              83.0
#
#    수축기혈압(최고) : mmHg  악력D : kg  앉아윗몸앞으로굽히기 : cm  교차윗몸일으키기 : 회  제자리 멀리뛰기 : cm 등급
# 0             150.0      40.6             12.2          30.0          179.0  C
# 1             119.0      22.1             16.0          32.0          165.0  B
# 2             153.0      45.9             13.2          61.0          216.0  B
# 3             132.0      43.6             16.0          45.0          231.0  A
# 4             106.0      33.5             10.6          46.0          198.0  C

# %%
# 전체데이터의 수축기혈압(최고) - 이완기혈압(최저)의 평균을 구하여라
df.columns
# Out:
# Index(['측정나이', '측정회원성별', '신장 : cm', '체중 : kg', '체지방율 : %', '이완기혈압(최저) : mmHg',
#        '수축기혈압(최고) : mmHg', '악력D : kg', '앉아윗몸앞으로굽히기 : cm', '교차윗몸일으키기 : 회',
#        '제자리 멀리뛰기 : cm', '등급'],
#       dtype='object')

# %%
ans=df['수축기혈압(최고) : mmHg']-df['이완기혈압(최저) : mmHg']
ans.mean()
# Out:
# 52.19539414750672

# %%
# 50~59세의 신장평균을 구하여라

df[(df.측정나이 >= 50) & (df.측정나이 <60)]['신장 : cm'].mean()
# Out:
# 164.07490107405314

# %%
# 연령대 (20~29 : 20대 …) 별 인원수를 구하여라


df['연령대']=df['측정나이']//10 *10
df.groupby('연령대').size()
# Out:
# 연령대
# 20.0    5831
# 30.0    2660
# 40.0    1801
# 50.0    1769
# 60.0    1335
# dtype: int64

# %%
# 연령대 (20~29 : 20대 …) 별 등급의 숫자를 데이터 프레임으로 표현하라

df[['연령대','등급']].value_counts().reset_index().sort_values('연령대')
# Out:
#      연령대 등급  count
# 0   20.0  A   1585
# 1   20.0  C   1455
# 2   20.0  B   1443
# 3   20.0  D   1348
# 4   30.0  A    743
# 5   30.0  B    697
# 6   30.0  C    626
# 7   30.0  D    594
# 14  40.0  A    386
# 12  40.0  B    428
# 11  40.0  C    455
# 9   40.0  D    532
# 13  50.0  B    410
# 8   50.0  D    564
# 17  50.0  A    321
# 10  50.0  C    474
# 18  60.0  A    314
# 15  60.0  B    371
# 16  60.0  C    339
# 19  60.0  D    311

# %%
df.groupby(['연령대','등급'],as_index=False).size()
# Out:
#      연령대 등급  size
# 0   20.0  A  1585
# 1   20.0  B  1443
# 2   20.0  C  1455
# 3   20.0  D  1348
# 4   30.0  A   743
# 5   30.0  B   697
# 6   30.0  C   626
# 7   30.0  D   594
# 8   40.0  A   386
# 9   40.0  B   428
# 10  40.0  C   455
# 11  40.0  D   532
# 12  50.0  A   321
# 13  50.0  B   410
# 14  50.0  C   474
# 15  50.0  D   564
# 16  60.0  A   314
# 17  60.0  B   371
# 18  60.0  C   339
# 19  60.0  D   311

# %%
aa=df[(df.등급=='A')&(df.측정회원성별 =='M')]['체지방율 : %'].mean()
dd=df[(df.등급=='D')&(df.측정회원성별 =='M')]['체지방율 : %'].mean()
abs(aa-dd)
# Out:
# 7.932086486137521

# %%
aa=df[(df.등급=='A')&(df.측정회원성별 =='F')]['체중 : kg'].mean()
dd=df[(df.등급=='D')&(df.측정회원성별 =='F')]['체중 : kg'].mean()
abs(aa-dd)
# Out:
# 5.176211590296504

# %%
#bmi는 자신의 몸무게(kg)를 키의 제곱(m)으로 나눈값이다. 데이터의 bmi 를 구한 새로운 컬럼을 만들고 남성의 bmi 평균을 구하여라
df['bmi']=(df['체중 : kg'] / df['신장 : cm']**2)

# %%
df[df.측정회원성별 == 'M'].bmi.mean()*10000
# Out:
# 24.46134409819308

# %%
# 남성과 여성의 교차윗몸일으키기 횟수의 평균의 차이를 구하여라

target=df.groupby('측정회원성별')['교차윗몸일으키기 : 회'].mean()
target.M-target.F
# Out:
# 14.243156833157627

# %% [markdown]
# # 기온 강수량 데이터

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/weather/weather2.csv")
df.head()
# Out:
#                   time  이화동강수  이화동기온  수영동강수  수영동기온
# 0  2020-01-01 00:00:00    0.1   -3.9    0.0    2.5
# 1  2020-01-01 01:00:00    0.0   -3.1    0.0    3.4
# 2  2020-01-01 02:00:00    0.0   -1.8    0.0    3.8
# 3  2020-01-01 03:00:00    0.0   -0.8    0.0    4.6
# 4  2020-01-01 04:00:00    0.0   -0.1    0.0    5.1

# %%
#여름철(6월,7월,8월) 이화동이 수영동보다 높은 기온을 가진 시간대는 몇개인가?

df.time=pd.to_datetime(df['time'])

# %%
summer=df[(df.time.dt.month == 6) |(df.time.dt.month == 7) |(df.time.dt.month == 8) ]
len(summer[summer.이화동기온 > summer.수영동기온].time.dt.hour)
# Out:
# 1415

# %%
# 이화동과 수영동의 최대강수량의 시간대를 각각 구하여라

df[df.이화동강수==df.이화동강수.max()].time
# Out:
# 6561   2020-09-30 09:00:00
# Name: time, dtype: datetime64[ns]

# %% [markdown]
# # 서비스 이탈예측 데이터

# %%
import pandas as pd
#데이터 로드
df = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/churn/train.csv")
df.head()
# Out:
#    RowNumber  CustomerId     Surname  CreditScore Geography  Gender  Age  \
# 0       6842    15793491  Cherkasova          714   Germany    Male   26
# 1       8963    15607874       Keane          687    France    Male   38
# 2       7047    15737627      Rivero          589   Germany  Female   20
# 3       7503    15697844  Whitehouse          721     Spain  Female   32
# 4       3439    15722404   Carpenter          445    France  Female   30
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       3  119545.48              2          1               0
# 1       0  144450.58              1          0               1
# 2       2  121093.29              2          1               0
# 3      10       0.00              1          1               0
# 4       3       0.00              2          1               1
#
#    EstimatedSalary  Exited
# 0         65482.94       0
# 1        137276.83       0
# 2          3529.72       0
# 3        136119.96       1
# ...

# %%
# 남성 이탈(Exited)이 가장 많은 국가(Geography)는 어디이고 이탈 인원은 몇명인가?
df[(df.Gender=='Male') & (df.Exited==1)].groupby('Geography').size().sort_values().tail(1)
# Out:
# Geography
# Germany    287
# dtype: int64

# %%
# **카드를 소유(HasCrCard ==1)하고 있으면서 활성멤버(IsActiveMember ==1) 인 고객들의 평균 나이를 소숫점이하 4자리까지 구하여라?
round(df[(df.HasCrCard == 1) & (df.IsActiveMember==1)].Age.mean(),4)
# Out:
# 39.6102

# %%
# Balance 값이 중간값 이상을 가지는 고객들의 CreditScore의 표준편차를 소숫점이하 3자리까지 구하여라

round(df[df.Balance >= df.Balance.median()].CreditScore.std(),3)
# Out:
# 97.295

# %% [markdown]
# # 성인 건강검진 데이터

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/smoke/train.csv")
df.columns
# Out:
# Index(['성별코드', '연령대코드(5세단위)', '신장(5Cm단위)', '체중(5Kg단위)', '허리둘레', '시력(좌)',
#        '시력(우)', '청력(좌)', '청력(우)', '수축기혈압', '이완기혈압', '식전혈당(공복혈당)', '총콜레스테롤',
#        '트리글리세라이드', 'HDL콜레스테롤', 'LDL콜레스테롤', '혈색소', '요단백', '혈청크레아티닌',
#        '(혈청지오티)AST', '(혈청지오티)ALT', '감마지티피', '흡연상태', '구강검진수검여부', '치아우식증유무',
#        '치석'],
#       dtype='object')

# %%
df.head()
# Out:
#   성별코드  연령대코드(5세단위)  신장(5Cm단위)  체중(5Kg단위)  허리둘레  시력(좌)  시력(우)  청력(좌)  청력(우)  \
# 0    F           55        145         55  73.0    0.7    0.5    1.0    1.0
# 1    M           40        180         55  74.0    1.5    1.5    1.0    1.0
# 2    F           55        150         50  72.0    1.0    0.2    1.0    1.0
# 3    M           40        170         85  89.0    1.0    0.8    1.0    1.0
# 4    F           40        155         45  62.0    0.5    1.0    1.0    1.0
#
#    수축기혈압  ...  요단백  혈청크레아티닌  (혈청지오티)AST  (혈청지오티)ALT  감마지티피  흡연상태  구강검진수검여부  \
# 0  129.0  ...  1.0      0.9       172.0       209.0   15.0     0         Y
# 1  102.0  ...  1.0      0.8        30.0        19.0   23.0     1         Y
# 2  116.0  ...  1.0      1.0        31.0        19.0   10.0     0         Y
# 3  124.0  ...  1.0      1.0        26.0        38.0  108.0     1         Y
# 4  127.0  ...  1.0      0.7        20.0        11.0   13.0     0         Y
#
#    치아우식증유무  치석   혈압차
# 0      0.0   Y  45.0
# ...

# %%
# 수축기혈압과 이완기 혈압기 수치의 차이를 새로운 컬럼(‘혈압차’) 으로 생성하고, 연령대 코드별 각 그룹 중 ‘혈압차’ 의 분산이 5번째로 큰 연령대 코드를 구하여라
df['혈압차']=df['수축기혈압']-df['이완기혈압']
df.groupby('연령대코드(5세단위)').혈압차.var().sort_values(ascending=False).index[4]
# Out:
# 60

# %%
#비만도를 나타내는 지표인 WHtR는 허리둘레 / 키로 표현한다. 일반적으로 0.58이상이면 비만으로 분류한다. 데이터중 WHtR 지표상 비만인 인원의 남/여 비율을 구하여라
df['WHtR']=df['허리둘레'] / df['신장(5Cm단위)']
data=df[df.WHtR > 0.58].성별코드.value_counts()
data.M / data.F
# Out:
# 1.2120996441281138

# %% [markdown]
# # 자동차 보험가입 예측데이터

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/insurance/train.csv")
df.head()
# Out:
#        id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0  188957  Female   25                1         17.0                   1
# 1  275631    Male   20                1         22.0                   0
# 2  329036  Female   40                1         41.0                   0
# 3  227288  Female   28                1         30.0                   1
# 4  300441  Female   50                1         28.0                   0
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0    < 1 Year             No         38785.0                 152.0       59
# 1    < 1 Year             No          2630.0                 160.0      113
# 2    1-2 Year            Yes         33165.0                 124.0      188
# 3    < 1 Year             No         29038.0                 152.0      233
# 4    1-2 Year            Yes         31325.0                 124.0      258
#
#    Response
# 0         0
# 1         0
# 2         0
# 3         0
# ...

# %%
# Vehicle_Age 값이 2년 이상인 사람들만 필터링 하고 그중에서 Annual_Premium 값이 전체 데이터의 중간값 이상인 사람들을 찾고, 그들의 Vintage값의 평균을 구하여라

df[(df.Vehicle_Age == '> 2 Years')&(df.Annual_Premium >= df.Annual_Premium.median())].Vintage.mean()
# Out:
# 154.43647182359118

# %%
#vehicle_age에 따른 각 성별(gender)그룹의 Annual_Premium값의 평균을 구하여 아래 테이블과 동일하게 구현하라

ans=df.groupby(['Vehicle_Age','Gender'],as_index=False).Annual_Premium.mean()
ans.pivot(index='Vehicle_Age',columns='Gender',values='Annual_Premium')
# Out:
# Gender             Female          Male
# Vehicle_Age
# 1-2 Year     30762.245001  30413.088469
# < 1 Year     29972.286702  30310.982212
# > 2 Years    36108.366374  35303.870627

# %% [markdown]
# # 핸드폰 가격 예측데이터

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/mobile/train.csv")
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
#price_range 의 각 value를 그룹핑하여 각 그룹의 n_cores 의 빈도가 가장높은 value와 그 빈도수를 구하여라
df.groupby(['price_range','n_cores']).size().sort_values().groupby(level=0).tail(1)
# Out:
# price_range  n_cores
# 0            2          69
# 3            5          70
# 2            4          73
# 1            1          76
# dtype: int64

# %%
# price_range 값이 3인 그룹에서 상관관계가 2번째로 높은 두 컬럼과 그 상관계수를 구하여라

ans=df[df.price_range==3].corr().unstack().sort_values(ascending=False)
ans[ans!=1].reset_index().iloc[1]
# Out:
# level_0          pc
# level_1          fc
# 0          0.635166
# Name: 1, dtype: object

# %% [markdown]
# # 비행탑승 경험 만족도 데이터

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/airline/train.csv")
df.head()
# Out:
#        id  Gender   Customer Type  Age   Type of Travel     Class  \
# 0   55882    Male  Loyal Customer   42  Business travel  Business
# 1   31906  Female  Loyal Customer   31  Business travel  Business
# 2   85481    Male  Loyal Customer   51  Personal Travel       Eco
# 3  102134    Male  Loyal Customer   44  Business travel  Business
# 4   31580    Male  Loyal Customer   33  Business travel  Business
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0              473                      1                                  1
# 1             3271                      4                                  4
# 2              214                      5                                  0
# 3             3097                      1                                  1
# 4             3286                      1                                  1
#
#    Ease of Online booking  ...  Inflight entertainment  On-board service  \
# ...

# %%
# Arrival Delay in Minutes 컬럼이 결측치인 데이터들 중 ‘neutral or dissatisfied’ 보다 ‘satisfied’의 수가 더 높은 Class는 어디 인가?

df.columns
# Out:
# Index(['id', 'Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
answer=df[df['Arrival Delay in Minutes'].isnull()==True].groupby(['Class','satisfaction'],as_index=False).size()
answer
# Out:
#       Class             satisfaction  size
# 0  Business  neutral or dissatisfied    36
# 1  Business                satisfied    76
# 2       Eco  neutral or dissatisfied   100
# 3       Eco                satisfied    25
# 4  Eco Plus  neutral or dissatisfied    15
# 5  Eco Plus                satisfied     4

# %% [markdown]
# # 수질 음용성 여부 데이터

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/waters/train.csv")
df.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0  7.918150  214.186611  23823.492888     7.290878  341.173322    411.424483
# 1  5.422446  205.266080  18542.957451     5.491963  306.702227    382.080129
# 2  7.341547  187.672402  21273.457066     7.784003         NaN    332.084293
# 3  9.056245  197.666301  17403.532167     7.688917  337.460176    414.766631
# 4  5.039374  142.860598  40829.353167     7.271543         NaN    386.803057
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       19.585002        25.057375   4.028958           0
# 1       10.504023        67.493450   2.911751           1
# 2       16.842334        55.019151   4.025644           0
# 3       15.349869        63.696746   3.319354           0
# 4       16.823773        52.297113   4.957420           0

# %%
# ph값은 상당히 많은 결측치를 포함한다. 결측치를 제외한 나머지 데이터들 중 사분위값 기준 하위 25%의 값들의 평균값은?
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2620 entries, 0 to 2619
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2225 non-null   float64
#  1   Hardness         2620 non-null   float64
#  2   Solids           2620 non-null   float64
#  3   Chloramines      2620 non-null   float64
#  4   Sulfate          2003 non-null   float64
#  5   Conductivity     2620 non-null   float64
#  6   Organic_carbon   2620 non-null   float64
#  7   Trihalomethanes  2488 non-null   float64
#  8   Turbidity        2620 non-null   float64
#  9   Potability       2620 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 204.8 KB

# %%
df=df['ph'].dropna()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 2225 entries, 0 to 2619
# Series name: ph
# Non-Null Count  Dtype
# --------------  -----
# 2225 non-null   float64
# dtypes: float64(1)
# memory usage: 34.8 KB

# %%
df[df <= df.quantile(0.25)].mean()
# Out:
# 5.057093462441731

# %% [markdown]
# # 의료 비용 예측 데이터

# %%
import pandas as pd
train = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/MedicalCost/train.csv")
train.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   64  female  39.330         0     no  northeast  14901.51670
# 1   47  female  27.830         0    yes  southeast  23065.42070
# 2   52  female  33.300         2     no  southwest  10806.83900
# 3   33  female  22.135         1     no  northeast   5354.07465
# 4   30    male  31.400         1     no  southwest   3659.34600

# %%
# 흡연자와 비흡연자 각각 charges의 상위 10% 그룹의 평균의 차이는?
yes=train[train.smoker=='yes'].charges.quantile(0.9).mean()
no=train[train.smoker=='no'].charges.quantile(0.9).mean()
yes-no
# Out:
# 32509.692970000004

# %% [markdown]
# # 킹카운티 주거지 가격예측문제 데이터

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/kingcountyprice//train.csv")
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  8961990160  20150413T000000  567500.0         3        2.5         2080
# 1  9455200205  20140604T000000  525000.0         3        2.0         1540
# 2  7853220670  20140918T000000  540000.0         3        2.5         2860
# 3  3298201170  20141110T000000  350000.0         3        1.0          940
# 4  7972604355  20140521T000000  218000.0         3        1.0         1020
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      4556     2.0           0     0  ...      8        2080              0
# 1      7800     1.0           0     0  ...      8        1540              0
# 2      8935     2.0           0     0  ...      8        2860              0
# 3      7811     1.0           0     0  ...      6         940              0
# 4      7874     1.0           0     0  ...      7        1020              0
#
# ...

# %%
# bedrooms 의 빈도가 가장 높은 값을 가지는 데이터들의 price의 상위 10%와 하위 10%값의 차이를 구하여라

top=df[df.bedrooms==df.bedrooms.value_counts().index[0]].price.quantile(0.9)
floor=df[df.bedrooms==df.bedrooms.value_counts().index[0]].price.quantile(0.1)

top-floor
# Out:
# 505500.0

# %%
df.bedrooms==df.bedrooms.value_counts()
# Out:
# bedrooms
# 3     7831
# 4     5487
# 2     2230
# 5     1284
# 6      230
# 1      164
# 7       32
# 0       12
# 8       10
# 9        6
# 10       2
# 33       1
# 11       1
# Name: count, dtype: int64

# %%
# 대학원 입학가능성 데이터
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/admission/train.csv")
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0         246        328          110                  4  4.0  2.5  9.02
# 1         100        323          113                  3  4.0  4.0  8.88
# 2          79        296           95                  2  3.0  2.0  7.54
# 3          53        334          116                  4  4.0  3.0  8.00
# 4         444        321          114                  5  4.5  4.5  9.16
#
#    Research  Chance of Admit
# 0         1             0.81
# 1         1             0.79
# 2         1             0.44
# 3         1             0.78
# 4         1             0.87

# %%
# Serial No. 컬럼을 제외하고 ‘Chance of Admit’을 종속변수, 나머지 변수를 독립변수라 할때, 랜덤포레스트를 통해 회귀 예측을 할 떄 변수중요도 값을 출력하

from sklearn.ensemble import RandomForestRegressor

df2=df.drop(df.columns[0],axis=1)
x=df2.drop(df2.columns[[-1]],axis=1)
y=df2[df2.columns[-1]]

# %%
ml = RandomForestRegressor()

ml.fit(x,y)
# Out:
# RandomForestRegressor()

# %%
pd.DataFrame({'importanc':ml.feature_importances_},x.columns)
# Out:
#                    importanc
# GRE Score           0.082682
# TOEFL Score         0.032379
# University Rating   0.012413
# SOP                 0.025380
# LOR                 0.023975
# CGPA                0.815415
# Research            0.007755

# %% [markdown]
# # 레드 와인 퀄리티 예측 데이터

# %%
# import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/redwine/train.csv")
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            5.0              0.38         0.01             1.6      0.048
# 1            5.0              0.42         0.24             2.0      0.060
# 2            7.1              0.36         0.30             1.6      0.080
# 3            7.6              0.29         0.49             2.7      0.092
# 4            7.7              0.51         0.28             2.1      0.087
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 26.0                  60.0  0.99084  3.70       0.75
# 1                 19.0                  50.0  0.99170  3.72       0.74
# 2                 35.0                  70.0  0.99693  3.44       0.50
# 3                 25.0                  60.0  0.99710  3.31       0.61
# 4                 23.0                  54.0  0.99800  3.42       0.74
#
#    alcohol  quality
# 0     14.0        6
# 1     14.0        8
# 2      9.4        5
# ...

# %%
# quality 값이 3인 그룹과 8인 데이터그룹의 각 컬럼별 독립변수의 표준편차 값의 차이를 구할때 그값이 가장 큰 컬럼명을 구하여라
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
(df[df.quality==3].std()-df[df.quality==8].std()).sort_values().index[0]
# Out:
# 'total sulfur dioxide'

# %% [markdown]
# # 약물 분류 데이터

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/drug/train.csv")
df.head()
# Out:
#    Age Sex      BP Cholesterol  Na_to_K  Drug
# 0   20   F  NORMAL      NORMAL    9.281     4
# 1   24   M    HIGH      NORMAL    9.475     1
# 2   34   M  NORMAL        HIGH   22.456     0
# 3   17   M  NORMAL      NORMAL   10.832     4
# 4   72   M     LOW        HIGH   16.310     0

# %%
df['age2']=df['Age'] // 10 *10
df.groupby('age2').Na_to_K.mean().to_frame()
# Out:
#         Na_to_K
# age2
# 10    17.603111
# 20    17.220038
# 30    15.656500
# 40    14.985273
# 50    15.810231
# 60    16.226045
# 70    14.413364

# %% [markdown]
# # 사기회사 분류 데이터

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/audit/train.csv")
df.head()
# Out:
#    Sector_score LOCATION_ID  PARA_A  Score_A  Risk_A  PARA_B  Score_B  Risk_B  \
# 0          2.72          14    4.53      0.6   2.718   87.93      0.6  52.758
# 1          3.41          16   12.68      0.6   7.608   41.00      0.6  24.600
# 2          2.72          11    3.11      0.6   1.866  113.97      0.6  68.382
# 3          3.41           8    1.12      0.4   0.448    0.00      0.2   0.000
# 4         55.57           9    1.06      0.4   0.424    0.00      0.2   0.000
#
#     TOTAL  numbers  ...  RiSk_E  History  Prob  Risk_F  Score  Inherent_Risk  \
# 0   92.46      5.0  ...     0.4        0   0.2     0.0    4.0        108.362
# 1   53.68      5.5  ...     0.4        0   0.2     0.0    4.4         41.936
# 2  117.08      5.5  ...     0.4        0   0.2     0.0    4.4         88.832
# 3    1.12      5.0  ...     0.4        0   0.2     0.0    2.2          1.848
# 4    1.06      5.0  ...     0.4        0   0.2     0.0    2.2          1.824
#
# ...

# %%
#데이터의 Risk 값에 따른 score_a와 score_b의 평균값을 구하여라

df.groupby('Risk')[['Score_A','Score_B']].mean()
# Out:
#        Score_A   Score_B
# Risk
# 0     0.262234  0.225532
# 1     0.490164  0.444262

# %% [markdown]
# # 센서데이터 동작유형 분류 데이터

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/muscle/train.csv")
df.head()
# Out:
#    motion_0  motion_1  motion_2  motion_3  motion_4  motion_5  motion_6  \
# 0      -6.0       8.0       5.0       6.0     -12.0     -27.0       5.0
# 1     -32.0      -3.0      -4.0      -5.0      -1.0      16.0       0.0
# 2      35.0      -2.0      -1.0       1.0     -25.0     -16.0      -3.0
# 3     -15.0      -6.0      -3.0      -5.0      27.0      37.0      -2.0
# 4      60.0       3.0       0.0      -7.0      -6.0     -10.0      -6.0
#
#    motion_7  motion_8  motion_9  ...  motion_55  motion_56  motion_57  \
# 0      24.0      -8.0      -5.0  ...       -1.0       -3.0       -6.0
# 1      -5.0      42.0       2.0  ...      -17.0      -12.0       -1.0
# 2     -20.0      10.0       1.0  ...        6.0      -65.0        6.0
# 3      -2.0      19.0       5.0  ...        2.0       11.0        0.0
# 4       7.0     -11.0      -4.0  ...      -12.0       17.0       -3.0
#
#    motion_58  motion_59  motion_60  motion_61  motion_62  motion_63  pose
# ...

# %%
# pose값에 따른 각 motion컬럼의 중간값의 가장 큰 차이를 보이는 motion컬럼은 어디이며 그값은?
t=df.groupby('pose').median().T
abs(t[0]-t[1])
# Out:
# motion_0     0.0
# motion_1     0.0
# motion_2     0.0
# motion_3     1.0
# motion_4     0.0
#             ...
# motion_59    1.0
# motion_60    2.0
# motion_61    2.0
# motion_62    4.0
# motion_63    0.0
# Length: 64, dtype: float64

# %%
t= df.groupby('pose').median().T
abs(t[0] - t[1]).sort_values().reset_index()
# Out:
#         index    0
# 0    motion_0  0.0
# 1   motion_24  0.0
# 2   motion_25  0.0
# 3   motion_26  0.0
# 4   motion_32  0.0
# ..        ...  ...
# 59  motion_30  3.0
# 60  motion_38  3.0
# 61  motion_46  3.5
# 62  motion_54  4.0
# 63  motion_62  4.0
#
# [64 rows x 2 columns]

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/hyundai/train.csv")
df.head()
# Out:
#      model  year  price transmission  mileage fuelType  tax(£)   mpg  \
# 0   Tucson  2016  12795       Manual    36263   Diesel      30  61.7
# 1      I10  2012   3995       Manual    22089   Petrol      20  61.4
# 2      I30  2019  24000       Manual      555   Petrol     145  34.0
# 3   Tucson  2017  12995       Manual    32147   Diesel      30  61.7
# 4   Tucson  2018  14991    Semi-Auto    32217   Diesel     150  57.6
#
#    engineSize
# 0         1.7
# 1         1.2
# 2         2.0
# 3         1.7
# 4         1.7

# %%
# 정보(row수)가 가장 많은 상위 3차종의 price값의 각 평균값은?

ans=set(df.groupby(['model']).size().sort_values().tail(3).index)

df[df.model.isin(ans)].groupby('model').price.mean().to_frame()
# Out:
#                 price
# model
#  I10      7646.137891
#  I30     11651.821759
#  Tucson  15805.441373

# %%
# import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/diabetes/train.csv")
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            3      102             74              0        0  29.5
# 1            2      144             58             33      135  31.6
# 2            5      136             82              0        0   0.0
# 3           13      145             82             19      110  22.2
# 4            1      117             60             23      106  33.8
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.121   32        0
# 1                     0.422   25        1
# 2                     0.640   69        0
# 3                     0.245   57        0
# 4                     0.466   27        0

# %%
# Outcome 값에 따른 각 그룹의 각 컬럼의 평균 차이를 구하여라

df.groupby('Outcome').mean().diff().iloc[1,:]
# Out:
# Pregnancies                  1.574159
# Glucose                     29.943995
# BloodPressure                3.202079
# SkinThickness                2.952033
# Insulin                     33.398645
# BMI                          4.541437
# DiabetesPedigreeFunction     0.143646
# Age                          5.866939
# Name: 1, dtype: float64

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/nflx/NFLX.csv")
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  2002-05-23  1.156429  1.242857  1.145714  1.196429   1.196429  104790000
# 1  2002-05-24  1.214286  1.225000  1.197143  1.210000   1.210000   11104800
# 2  2002-05-28  1.213571  1.232143  1.157143  1.157143   1.157143    6609400
# 3  2002-05-29  1.164286  1.164286  1.085714  1.103571   1.103571    6757800
# 4  2002-05-30  1.107857  1.107857  1.071429  1.071429   1.071429   10154200

# %%
#매년 5월달의 open가격의 평균값을 데이터 프레임으로 표현하라

df.Date=pd.to_datetime(df['Date'])
df2=df[df.Date.dt.month==5].reset_index()
df2
# Out:
#      index       Date        Open        High         Low       Close  \
# 0        0 2002-05-23    1.156429    1.242857    1.145714    1.196429
# 1        1 2002-05-24    1.214286    1.225000    1.197143    1.210000
# 2        2 2002-05-28    1.213571    1.232143    1.157143    1.157143
# 3        3 2002-05-29    1.164286    1.164286    1.085714    1.103571
# 4        4 2002-05-30    1.107857    1.107857    1.071429    1.071429
# ..     ...        ...         ...         ...         ...         ...
# 401   4783 2021-05-24  501.049988  504.250000  499.510010  502.899994
# 402   4784 2021-05-25  506.000000  506.369995  499.220001  501.339996
# 403   4785 2021-05-26  502.339996  504.140015  500.500000  502.359985
# 404   4786 2021-05-27  501.799988  505.100006  498.540009  503.859985
# 405   4787 2021-05-28  504.399994  511.760010  502.529999  502.809998
#
#       Adj Close     Volume
# 0      1.196429  104790000
# 1      1.210000   11104800
# 2      1.157143    6609400
# ...

# %%
target=df.groupby(df.Date.dt.strftime('%Y-%m')).mean()
target[target.index.str.contains('-05')].Open.to_frame()
# Out:
#                Open
# Date
# 2002-05    1.155833
# 2003-05    1.641497
# 2004-05    4.261143
# 2005-05    1.951905
# 2006-05    4.163571
# 2007-05    3.159351
# 2008-05    4.435034
# 2009-05    5.790571
# 2010-05   14.417071
# 2011-05   34.650272
# 2012-05   10.523247
# 2013-05   31.936429
# 2014-05   51.121292
# 2015-05   85.057429
# 2016-05   92.705715
# 2017-05  158.255455
# 2018-05  329.779541
# 2019-05  359.664548
# 2020-05  433.880499
# 2021-05  496.923996
