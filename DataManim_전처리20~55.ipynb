# %%
import pandas as pd

data='https://raw.githubusercontent.com/Datamanim/pandas/main/chipo.csv'
df=pd.read_csv(data)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# quantity컬럼 값이 3인 데이터를 추출하여 첫 5행을 출력하라

df.loc[df['quantity']==3].head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         3           Chips and Fresh Tomato Salsa
# 1         1         3                                   Izze
# 2         1         3                       Nantucket Nectar
# 3         1         3  Chips and Tomatillo-Green Chili Salsa
# 4         2         3                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
#quantity컬럼 값이 3인 데이터를 추출하여 index를 0부터 정렬하고 첫 5행을 출력하라
df.loc[df['quantity']==3].head().reset_index(drop=True)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         3           Chips and Fresh Tomato Salsa
# 1         1         3                                   Izze
# 2         1         3                       Nantucket Nectar
# 3         1         3  Chips and Tomatillo-Green Chili Salsa
# 4         2         3                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
# quantity , item_price 두개의 컬럼으로 구성된 새로운 데이터 프레임을 정의하라
df[['quantity','item_price']]
# Out:
#       quantity item_price
# 0            3     $2.39
# 1            3     $3.39
# 2            3     $3.39
# 3            3     $2.39
# 4            3    $16.98
# ...        ...        ...
# 4617         3    $11.75
# 4618         3    $11.75
# 4619         3    $11.25
# 4620         3     $8.75
# 4621         3     $8.75
#
# [4622 rows x 2 columns]

# %%
# item_price 컬럼의 달러표시 문자를 제거하고 float 타입으로 저장하여 new_price 컬럼에 저장하라
df['new_price']=df['item_price'].str[1:].astype('float')
df['new_price'].head()
# Out:
# 0     2.39
# 1     3.39
# 2     3.39
# 3     2.39
# 4    16.98
# Name: new_price, dtype: float64

# %%
# new_price 컬럼이 5이하의 값을 가지는 데이터프레임을 추출하고, 전체 갯수를 구하여라
len(df.loc[df.new_price<=5])
# Out:
# 1652

# %%
#item_name명이 Chicken Salad Bowl 인 데이터 프레임을 추출하라고 index 값을 초기화하여라

df[df.item_name=='Chicken Salad Bowl'].reset_index(drop=True)
# Out:
#       order_id  quantity           item_name  \
# 0            1         3  Chicken Salad Bowl
# 1            1         3  Chicken Salad Bowl
# 2            1         3  Chicken Salad Bowl
# 3            1         3  Chicken Salad Bowl
# 4            2         3  Chicken Salad Bowl
# ...        ...       ...                 ...
# 4617      1833         3  Chicken Salad Bowl
# 4618      1833         3  Chicken Salad Bowl
# 4619      1834         3  Chicken Salad Bowl
# 4620      1834         3  Chicken Salad Bowl
# 4621      1834         3  Chicken Salad Bowl
#
#                                      choice_description item_price  new_price
# 0                                                   NaN     $2.39        2.39
# 1                                          [Clementine]     $3.39        3.39
# 2                                               [Apple]     $3.39        3.39
# 3                                                   NaN     $2.39        2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98       16.98
# ...                                                 ...        ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75       11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75       11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25       11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75        8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75        8.75
#
# [4622 rows x 6 columns]

# %%
#new_price값이 9 이하이고 item_name 값이 Chicken Salad Bowl 인 데이터 프레임을 추출하라
df[(df.new_price <=9 ) & (df.item_name=='Chicken Salad Bowl')]
# Out:
#       order_id  quantity           item_name  \
# 0            1         3  Chicken Salad Bowl
# 1            1         3  Chicken Salad Bowl
# 2            1         3  Chicken Salad Bowl
# 3            1         3  Chicken Salad Bowl
# 6            3         3  Chicken Salad Bowl
# ...        ...       ...                 ...
# 4614      1831         3  Chicken Salad Bowl
# 4615      1832         3  Chicken Salad Bowl
# 4616      1832         3  Chicken Salad Bowl
# 4620      1834         3  Chicken Salad Bowl
# 4621      1834         3  Chicken Salad Bowl
#
#                                      choice_description item_price  new_price
# 0                                                   NaN     $2.39        2.39
# 1                                          [Clementine]     $3.39        3.39
# 2                                               [Apple]     $3.39        3.39
# 3                                                   NaN     $2.39        2.39
# 6                                                   NaN     $1.69        1.69
# ...                                                 ...        ...        ...
# 4614                                                NaN     $1.50        1.50
# 4615   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]     $8.75        8.75
# 4616                                                NaN     $4.45        4.45
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75        8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75        8.75
#
# [3077 rows x 6 columns]

# %%
#df의 new_price 컬럼 값에 따라 오름차순으로 정리하고 index를 초기화 하여라
df.sort_values('new_price').reset_index(drop=True)
# Out:
#       order_id  quantity           item_name  \
# 0          471         3  Chicken Salad Bowl
# 1          338         3  Chicken Salad Bowl
# 2         1575         3  Chicken Salad Bowl
# 3           47         3  Chicken Salad Bowl
# 4         1014         3  Chicken Salad Bowl
# ...        ...       ...                 ...
# 4617      1443         3  Chicken Salad Bowl
# 4618      1443         3  Chicken Salad Bowl
# 4619       511         3  Chicken Salad Bowl
# 4620      1398         3  Chicken Salad Bowl
# 4621      1443         3  Chicken Salad Bowl
#
#                                      choice_description item_price  new_price
# 0                                                   NaN     $1.09        1.09
# 1                                           [Coca Cola]     $1.09        1.09
# 2                                          [Dr. Pepper]     $1.09        1.09
# 3                                          [Dr. Pepper]     $1.09        1.09
# 4                                           [Coca Cola]     $1.09        1.09
# ...                                                 ...        ...        ...
# 4617  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $33.75       33.75
# 4618  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...    $35.00       35.00
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $35.00       35.00
# 4620  [Roasted Chili Corn Salsa, [Fajita Vegetables,...    $35.25       35.25
# 4621                                                NaN    $44.25       44.25
#
# [4622 rows x 6 columns]

# %%
#df의 item_name 컬럼 값중 Chips 포함하는 경우의 데이터를 출력하라
df.loc[df.item_name.str.contains('Chicken')]
# Out:
#       order_id  quantity           item_name  \
# 0            1         3  Chicken Salad Bowl
# 1            1         3  Chicken Salad Bowl
# 2            1         3  Chicken Salad Bowl
# 3            1         3  Chicken Salad Bowl
# 4            2         3  Chicken Salad Bowl
# ...        ...       ...                 ...
# 4617      1833         3  Chicken Salad Bowl
# 4618      1833         3  Chicken Salad Bowl
# 4619      1834         3  Chicken Salad Bowl
# 4620      1834         3  Chicken Salad Bowl
# 4621      1834         3  Chicken Salad Bowl
#
#                                      choice_description item_price  new_price
# 0                                                   NaN     $2.39        2.39
# 1                                          [Clementine]     $3.39        3.39
# 2                                               [Apple]     $3.39        3.39
# 3                                                   NaN     $2.39        2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98       16.98
# ...                                                 ...        ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75       11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75       11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25       11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75        8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75        8.75
#
# [4622 rows x 6 columns]

# %%
#df의 짝수번째 컬럼만을 포함하는 데이터프레임을 출력하라

df.iloc[:,::2]
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
#df의 new_price 컬럼 값에 따라 내림차순으로 정리하고 index를 초기화 하여라
df.sort_values('item_price',ascending=False).reset_index(drop=True)
# Out:
#       order_id  quantity            item_name  \
# 0         1042         1     Steak Salad Bowl
# 1         1762         1     Steak Salad Bowl
# 2         1615         1     Steak Salad Bowl
# 3          738         1  Barbacoa Salad Bowl
# 4         1243         1  Carnitas Salad Bowl
# ...        ...       ...                  ...
# 4617      1254         1          Canned Soda
# 4618       180         1          Canned Soda
# 4619      1262         1          Canned Soda
# 4620       338         1          Canned Soda
# 4621       591         1          Canned Soda
#
#                                      choice_description item_price
# 0     [Fresh Tomato Salsa, [Black Beans, Sour Cream,...     $9.39
# 1     [Roasted Chili Corn Salsa, [Fajita Vegetables,...     $9.39
# 2     [Fresh Tomato Salsa, [Fajita Vegetables, Chees...     $9.39
# 3     [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...     $9.39
# 4     [Tomatillo Green Chili Salsa, [Rice, Pinto Bea...     $9.39
# ...                                                 ...        ...
# 4617                                  [Diet Dr. Pepper]     $1.09
# 4618                                       [Dr. Pepper]     $1.09
# 4619                                        [Coca Cola]     $1.09
# 4620                                        [Coca Cola]     $1.09
# 4621                                           [Sprite]     $1.09
#
# [4622 rows x 5 columns]

# %%
#df의 item_name 컬럼 값이 Steak Salad 또는 Bowl 인 데이터를 인덱싱하라

df[(df.item_name == 'Steak Salad') | (df.item_name == 'Bowl')]
# Out:
#       order_id  quantity    item_name  \
# 445        193         3         Bowl
# 664        276         1  Steak Salad
# 673        279         1         Bowl
# 752        311         1  Steak Salad
# 893        369         1  Steak Salad
# 3502      1406         1  Steak Salad
#
#                                      choice_description item_price
# 445   [Braised Carnitas, Pinto Beans, [Sour Cream, C...    $22.20
# 664   [Tomatillo-Red Chili Salsa (Hot), [Black Beans...     $8.99
# 673   [Adobo-Marinated and Grilled Steak, [Sour Crea...     $7.40
# 752   [Tomatillo-Red Chili Salsa (Hot), [Black Beans...     $8.99
# 893   [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...     $8.99
# 3502                        [[Lettuce, Fajita Veggies]]     $8.69

# %%
#df의 item_name 컬럼 값이 Steak Salad 또는 Bowl 인 데이터를 데이터 프레임화 한 후, item_name를 기준으로 중복행이 있으면 제거하되 첫번째 케이스만 남겨라
ans=df[(df.item_name == "Steak Salad") |( df.item_name=="Bowl" ) ]
ans.drop_duplicates('item_name')
# Out:
#      order_id  quantity    item_name  \
# 445       193         3         Bowl
# 664       276         1  Steak Salad
#
#                                     choice_description item_price
# 445  [Braised Carnitas, Pinto Beans, [Sour Cream, C...    $22.20
# 664  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...     $8.99

# %%
#df의 item_name 컬럼 값이 Steak Salad 또는 Bowl 인 데이터를 데이터 프레임화 한 후, item_name를 기준으로 중복행이 있으면 제거하되 마지막 케이스만 남겨라
ans=df[(df.item_name == "Steak Salad") |( df.item_name=="Bowl" ) ]
ans.drop_duplicates('item_name',keep='last')
# Out:
#       order_id  quantity    item_name  \
# 673        279         1         Bowl
# 3502      1406         1  Steak Salad
#
#                                      choice_description item_price
# 673   [Adobo-Marinated and Grilled Steak, [Sour Crea...     $7.40
# 3502                        [[Lettuce, Fajita Veggies]]     $8.69

# %%
ans=df.loc[df.new_price >= df.new_price.mean()]
ans
# Out:
#       order_id  quantity           item_name  \
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# 8            4         1    Steak Soft Tacos
# 9            5         1       Steak Burrito
# ...        ...       ...                 ...
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price  new_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98       10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75       11.75
# 8     [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25        9.25
# 9     [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25        9.25
# ...                                                 ...        ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75       11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75       11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25       11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75        8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75        8.75
#
# [2890 rows x 6 columns]

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price  new_price
# 0                                                NaN     $2.39        2.39
# 1                                       [Clementine]     $3.39        3.39
# 2                                            [Apple]     $3.39        3.39
# 3                                                NaN     $2.39        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98       16.98

# %%
df.loc[df.item_name=='Izze','item_name']='Fizzy Lizzy'
ans=df
ans
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                            Fizzy Lizzy
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price  new_price
# 0                                                   NaN     $2.39        2.39
# 1                                          [Clementine]     $3.39        3.39
# 2                                               [Apple]     $3.39        3.39
# 3                                                   NaN     $2.39        2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98       16.98
# ...                                                 ...        ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75       11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75       11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25       11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75        8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75        8.75
#
# [4622 rows x 6 columns]

# %%
#df의 데이터 중 choice_description 값이 NaN 인 데이터의 갯수를 구하여라

df.loc[df.choice_description.isnull(),'choice_description']='NoData'
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                            Fizzy Lizzy
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price  new_price
# 0                                                NoData     $2.39        2.39
# 1                                          [Clementine]     $3.39        3.39
# 2                                               [Apple]     $3.39        3.39
# 3                                                NoData     $2.39        2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98       16.98
# ...                                                 ...        ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75       11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75       11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25       11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75        8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75        8.75
#
# [4622 rows x 6 columns]

# %%
#df의 데이터 중 choice_description 값에 Black이 들어가는 경우를 인덱싱하라
df[df.choice_description.str.contains('Black')]
# Out:
#       order_id  quantity             item_name  \
# 4            2         2          Chicken Bowl
# 7            4         1         Steak Burrito
# 9            5         1         Steak Burrito
# 11           6         1  Chicken Crispy Tacos
# 12           6         1    Chicken Soft Tacos
# ...        ...       ...                   ...
# 4604      1828         1          Chicken Bowl
# 4608      1829         1        Veggie Burrito
# 4611      1830         1        Veggie Burrito
# 4612      1831         1         Carnitas Bowl
# 4617      1833         1         Steak Burrito
#
#                                      choice_description item_price  new_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98       16.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75       11.75
# 9     [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25        9.25
# 11    [Roasted Chili Corn Salsa, [Fajita Vegetables,...     $8.75        8.75
# 12    [Roasted Chili Corn Salsa, [Rice, Black Beans,...     $8.75        8.75
# ...                                                 ...        ...        ...
# 4604  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...     $8.75        8.75
# 4608  [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.25       11.25
# 4611  [Tomatillo Green Chili Salsa, [Rice, Fajita Ve...    $11.25       11.25
# 4612  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...     $9.25        9.25
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75       11.75
#
# [1353 rows x 6 columns]

# %%
#df의 데이터 중 choice_description 값에 Vegetables 들어가지 않는 경우의 갯수를 출력하라
df.count()-df.loc[df.choice_description.str.contains("Vegetables")].count()
# Out:
# order_id              3900
# quantity              3900
# item_name             3900
# choice_description    3900
# item_price            3900
# new_price             3900
# dtype: int64

# %%
df[df.item_name.str.startswith('N')]
# Out:
#       order_id  quantity         item_name         choice_description  \
# 2            1         1  Nantucket Nectar                    [Apple]
# 22          11         1  Nantucket Nectar       [Pomegranate Cherry]
# 105         46         1  Nantucket Nectar  [Pineapple Orange Banana]
# 173         77         1  Nantucket Nectar                    [Apple]
# 205         91         1  Nantucket Nectar             [Peach Orange]
# 436        189         1  Nantucket Nectar       [Pomegranate Cherry]
# 601        247         2  Nantucket Nectar  [Pineapple Orange Banana]
# 925        381         1  Nantucket Nectar       [Pomegranate Cherry]
# 1356       553         1  Nantucket Nectar       [Pomegranate Cherry]
# 1585       641         1  Nantucket Nectar             [Peach Orange]
# 1626       656         1  Nantucket Nectar  [Pineapple Orange Banana]
# 1706       690         1  Nantucket Nectar                    [Apple]
# 2162       872         1  Nantucket Nectar  [Pineapple Orange Banana]
# 2379       947         2  Nantucket Nectar             [Peach Orange]
# 2381       947         1  Nantucket Nectar                    [Apple]
# 2430       965         1  Nantucket Nectar       [Pomegranate Cherry]
# 2653      1053         1  Nantucket Nectar  [Pineapple Orange Banana]
# 2818      1118         1  Nantucket Nectar                    [Apple]
# 2838      1128         1  Nantucket Nectar             [Peach Orange]
# 2853      1133         1  Nantucket Nectar                    [Apple]
# 2949      1172         1  Nantucket Nectar             [Peach Orange]
# 3318      1330         1  Nantucket Nectar             [Peach Orange]
# 3368      1351         1  Nantucket Nectar  [Pineapple Orange Banana]
# 3570      1433         1  Nantucket Nectar  [Pineapple Orange Banana]
# 3845      1541         1  Nantucket Nectar             [Peach Orange]
# 4019      1609         1  Nantucket Nectar  [Pineapple Orange Banana]
# 4078      1632         1  Nantucket Nectar             [Peach Orange]
#
#      item_price  new_price
# 2        $3.39        3.39
# 22       $3.39        3.39
# 105      $3.39        3.39
# 173      $3.39        3.39
# 205      $3.39        3.39
# 436      $3.39        3.39
# 601      $6.78        6.78
# 925      $3.39        3.39
# 1356     $3.39        3.39
# 1585     $3.39        3.39
# 1626     $3.39        3.39
# 1706     $3.39        3.39
# 2162     $3.39        3.39
# 2379     $6.78        6.78
# 2381     $3.39        3.39
# 2430     $3.39        3.39
# 2653     $3.39        3.39
# 2818     $3.39        3.39
# 2838     $3.39        3.39
# 2853     $3.39        3.39
# 2949     $3.39        3.39
# 3318     $3.39        3.39
# 3368     $3.39        3.39
# 3570     $3.39        3.39
# 3845     $3.39        3.39
# 4019     $3.39        3.39
# 4078     $3.39        3.39

# %%
#df의 데이터 중 item_name 값의 단어갯수가 15개 이상인 데이터를 인덱싱하라

df.loc[df.item_name.str.len()>15]
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 8            4         1                       Steak Soft Tacos
# 10           5         1                    Chips and Guacamole
# ...        ...       ...                                    ...
# 4615      1832         1                     Chicken Soft Tacos
# 4616      1832         1                    Chips and Guacamole
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price  new_price
# 0                                                NoData     $2.39        2.39
# 2                                               [Apple]     $3.39        3.39
# 3                                                NoData     $2.39        2.39
# 8     [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25        9.25
# 10                                               NoData     $4.45        4.45
# ...                                                 ...        ...        ...
# 4615   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]     $8.75        8.75
# 4616                                             NoData     $4.45        4.45
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25       11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75        8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75        8.75
#
# [1820 rows x 6 columns]

# %%
#df의 데이터 중 new_price값이 lst에 해당하는 경우의 데이터 프레임을 구하고 그 갯수를 출력하라

lst =[1.69, 2.39, 3.39, 4.45, 9.25, 10.98, 11.75, 16.98]
len(df.loc[df.new_price.isin(lst)])
# Out:
# 1393

# %%
Url = 'https://raw.githubusercontent.com/Datamanim/pandas/main/AB_NYC_2019.csv'
df=pd.read_csv(Url)

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %%
df.groupby('host_name').size().head()
# Out:
# host_name
# 'Cil                        1
# (Ari) HENRY LEE             1
# (Email hidden by Airbnb)    6
# (Mary) Haiy                 1
# -TheQueensCornerLot         1
# dtype: int64

# %%
df.groupby('host_name').size().to_frame().rename(columns={0:'counts'}).sort_values('counts',ascending=False)
# Out:
#               counts
# host_name
# Michael          417
# David            403
# Sonder (NYC)     327
# John             294
# Alex             279
# ...              ...
# Jerbean            1
# Jerald             1
# Jeonghoon          1
# Jeny               1
# 현선                 1
#
# [11452 rows x 1 columns]

# %%
#neighbourhood_group의 값에 따른 neighbourhood컬럼 값의 갯수를 구하여라
df.groupby(['neighbourhood_group','neighbourhood'],as_index=False).size()
# Out:
#     neighbourhood_group  neighbourhood  size
# 0                 Bronx       Allerton    42
# 1                 Bronx     Baychester     7
# 2                 Bronx        Belmont    24
# 3                 Bronx      Bronxdale    19
# 4                 Bronx    Castle Hill     9
# ..                  ...            ...   ...
# 216       Staten Island    Tottenville     7
# 217       Staten Island  West Brighton    18
# 218       Staten Island    Westerleigh     2
# 219       Staten Island    Willowbrook     1
# 220       Staten Island        Woodrow     1
#
# [221 rows x 3 columns]

# %%
#neighbourhood_group의 값에 따른 neighbourhood컬럼 값 중 neighbourhood_group그룹의 최댓값들을 출력하라

Ans= df.groupby(['neighbourhood_group','neighbourhood'], as_index=False).size()\
                  .groupby(['neighbourhood_group'], as_index=False).max()

# %%
Ans
# Out:
#   neighbourhood_group    neighbourhood  size
# 0               Bronx         Woodlawn    70
# 1            Brooklyn  Windsor Terrace  3920
# 2           Manhattan     West Village  2658
# 3              Queens         Woodside   900
# 4       Staten Island          Woodrow    48

# %%
df[['neighbourhood_group','reviews_per_month']].groupby('neighbourhood_group').describe()
# Out:
#                     reviews_per_month                                          \
#                                 count      mean       std   min     25%   50%
# neighbourhood_group
# Bronx                           876.0  1.837831  1.673284  0.02  0.4800  1.38
# Brooklyn                      16447.0  1.283212  1.516259  0.01  0.1800  0.66
# Manhattan                     16632.0  1.272131  1.628252  0.01  0.1700  0.61
# Queens                         4574.0  1.941200  2.213108  0.01  0.3700  1.21
# Staten Island                   314.0  1.872580  1.685495  0.02  0.7025  1.41
#
#
#                        75%    max
# neighbourhood_group
# Bronx                2.790  10.34
# Brooklyn             1.980  14.00
# Manhattan            1.890  58.50
# Queens               2.790  20.94
# Staten Island        2.615  10.12

# %%
# neighbourhood 값과 neighbourhood_group 값에 따른 price 의 평균을 구하라
df.groupby(['neighbourhood','neighbourhood_group']).price.mean()
# Out:
# neighbourhood    neighbourhood_group
# Allerton         Bronx                   87.595238
# Arden Heights    Staten Island           67.250000
# Arrochar         Staten Island          115.000000
# Arverne          Queens                 171.779221
# Astoria          Queens                 117.187778
#                                            ...
# Windsor Terrace  Brooklyn               138.993631
# Woodhaven        Queens                  67.170455
# Woodlawn         Bronx                   60.090909
# Woodrow          Staten Island          700.000000
# Woodside         Queens                  85.097872
# Name: price, Length: 221, dtype: float64

# %%
df.groupby(['neighbourhood','neighbourhood_group']).price.mean().unstack()
# Out:
# neighbourhood_group      Bronx    Brooklyn  Manhattan      Queens  \
# neighbourhood
# Allerton             87.595238         NaN        NaN         NaN
# Arden Heights              NaN         NaN        NaN         NaN
# Arrochar                   NaN         NaN        NaN         NaN
# Arverne                    NaN         NaN        NaN  171.779221
# Astoria                    NaN         NaN        NaN  117.187778
# ...                        ...         ...        ...         ...
# Windsor Terrace            NaN  138.993631        NaN         NaN
# Woodhaven                  NaN         NaN        NaN   67.170455
# Woodlawn             60.090909         NaN        NaN         NaN
# Woodrow                    NaN         NaN        NaN         NaN
# Woodside                   NaN         NaN        NaN   85.097872
#
# neighbourhood_group  Staten Island
# neighbourhood
# Allerton                       NaN
# Arden Heights                67.25
# Arrochar                    115.00
# Arverne                        NaN
# Astoria                        NaN
# ...                            ...
# Windsor Terrace                NaN
# Woodhaven                      NaN
# Woodlawn                       NaN
# Woodrow                     700.00
# Woodside                       NaN
#
# [221 rows x 5 columns]

# %%
Ans = df.groupby(['neighbourhood','neighbourhood_group']).price.mean().unstack().fillna(-999)

# %%
Ans
# Out:
# neighbourhood_group       Bronx    Brooklyn  Manhattan      Queens  \
# neighbourhood
# Allerton              87.595238 -999.000000     -999.0 -999.000000
# Arden Heights       -999.000000 -999.000000     -999.0 -999.000000
# Arrochar            -999.000000 -999.000000     -999.0 -999.000000
# Arverne             -999.000000 -999.000000     -999.0  171.779221
# Astoria             -999.000000 -999.000000     -999.0  117.187778
# ...                         ...         ...        ...         ...
# Windsor Terrace     -999.000000  138.993631     -999.0 -999.000000
# Woodhaven           -999.000000 -999.000000     -999.0   67.170455
# Woodlawn              60.090909 -999.000000     -999.0 -999.000000
# Woodrow             -999.000000 -999.000000     -999.0 -999.000000
# Woodside            -999.000000 -999.000000     -999.0   85.097872
#
# neighbourhood_group  Staten Island
# neighbourhood
# Allerton                   -999.00
# Arden Heights                67.25
# Arrochar                    115.00
# Arverne                    -999.00
# Astoria                    -999.00
# ...                            ...
# Windsor Terrace            -999.00
# Woodhaven                  -999.00
# Woodlawn                   -999.00
# Woodrow                     700.00
# Woodside                   -999.00
#
# [221 rows x 5 columns]
